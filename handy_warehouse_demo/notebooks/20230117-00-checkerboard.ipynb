# %%
# %load_ext autoreload
# %autoreload 2

import sys

sys.path.insert(0, "../src")

# %%
import matplotlib.pyplot as plt
from generate_texture import draw_checkerboard

texture = draw_checkerboard(5, shape=(400, 400, 3))
plt.imshow(texture)
plt.show()

# %% [markdown]
# Here's the command that we'll actually use to generate the image:

# %%
! python \
    ../src/generate_texture.py \
    --n_grid 5 \
    --output ../models/textured_box/materials/textures/grid.png
